# %% [markdown]
# # 01 Full Pipeline Sentiment Trend Forecasting

# %% [markdown]
# ## 1. Project introduction

# %% [markdown]
# ## 2. Dataset automatic download

# %% [markdown]
# ## 3. Data cleaning

# %% [markdown]
# ## 4. Sentiment label construction

# %% [markdown]
# ## 5. Time-based train/validation/test split

# %% [markdown]
# ## 6. DistilBERT fine-tuning

# %% [markdown]
# ## 7. Text sentiment evaluation

# %% [markdown]
# ## 8. Sentiment score generation

# %% [markdown]
# ## 9. Weekly time series construction

# %% [markdown]
# ## 10. LSTM trend forecasting

# %% [markdown]
# ## 11. Baseline comparison

# %% [markdown]
# ## 12. Final findings and discussion

# %% [markdown]
# ## 13. Six-member contribution table

# %%
# !python src/01_download_data.py
# !python src/02_preprocess_data.py
# !python src/03_train_sentiment_model.py --sample_size 100000 --epochs 3 --batch_size 16
# !python src/04_evaluate_sentiment_model.py
# !python src/05_generate_sentiment_scores.py --batch_size 64
# !python src/06_build_timeseries.py
# !python src/07_train_lstm_forecaster.py --epochs 100 --look_back 12
# !python src/08_baseline_models.py
# !python src/09_visualize_results.py
